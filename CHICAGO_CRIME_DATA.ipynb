# %%
# !pip install ipython-sql
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# ...
#      |████████████████████████████████| 42 kB 2.0 MB/s  eta 0:00:01
# ...
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13698 sha256=8b2415fdc7fb50350b1eaf978f2802fa74bb2b54d937dcf431d38ee7e264559c
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/8c/76/0b/eb9eb3da7e2335e3577e3f96a0ae9f74f206e26457bd1a2bc8
# Successfully built prettytable
# ...

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# Remember the connection string is of the format:
# %sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name
# Enter the connection string for your Db2 on Cloud database instance below
# %sql ibm_db_sa://pzt67887:wjh2qkcd%2B2xsmgtp@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB

# %%
# Rows in Crime table
# Problem 1: Find the total number of crimes recorded in the CRIME table.
# %sql select count(*) from CHICAGO_CRIME_DATA
# Out:
#  * ibm_db_sa://pzt67887:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('533'),)]

# %%
# Problem 2: List community areas with per capita income less than 11000.
# %sql select community_area_name , per_capita_income FROM CENSUS_DATA where per_capita_income <11000
# Out:
#  * ibm_db_sa://pzt67887:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('West Garfield Park', 10934),
#  ('South Lawndale', 10402),
#  ('Fuller Park', 10432),
#  ('Riverdale', 8201)]

# %%
# Problem 3: List all case numbers for crimes involving minors?
# %sql select case_number from CHICAGO_CRIME_DATA where DESCRIPTION like '%MINOR'
# Out:
#  * ibm_db_sa://pzt67887:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('HL266884',), ('HK238408',)]

# %%
# Problem 4: List all kidnapping crimes involving a child?(children are not considered minors for the purposes of crime analysis)
# %sql select * from CHICAGO_CRIME_DATA WHERE PRIMARY_TYPE = 'KIDNAPPING' and DESCRIPTION like '%CHILD%'
# Out:
#  * ibm_db_sa://pzt67887:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(5276766, 'HN144152', datetime.date(2007, 1, 26), '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 'FALSE', 'FALSE', 1533, 15, 29, 25, '20', 1143050, 1897546, 2007, Decimal('41.87490841'), Decimal('-87.75024931'), '(41.874908413, -87.750249307)')]

# %%
# Problem 5: What kind of crimes were recorded at schools?
# %sql select DISTINCT(PRIMARY_TYPE) from CHICAGO_CRIME_DATA where LOCATION_DESCRIPTION like '%SCHOOL%'
# Out:
#  * ibm_db_sa://pzt67887:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('ASSAULT',),
#  ('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('CRIMINAL TRESPASS',),
#  ('NARCOTICS',),
#  ('PUBLIC PEACE VIOLATION',)]

# %%
#Problem 6: List the average safety score for all types of schools.
# %sql select "Elementary, Middle, or High School", avg(SAFETY_SCORE) from CHICAGO_PUBLIC_SCHOOLS GROUP BY "Elementary, Middle, or High School"
# Out:
#  * ibm_db_sa://pzt67887:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('ES', Decimal('49.520383')),
#  ('HS', Decimal('49.623529')),
#  ('MS', Decimal('48.000000'))]

# %%
# Problem 7: List 5 community areas with highest % of households below poverty line.
# %sql select * from CENSUS_DATA ORDER BY PERCENT_HOUSEHOLDS_BELOW_POVERTY DESC LIMIT 5
# Out:
#  * ibm_db_sa://pzt67887:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(54, 'Riverdale', Decimal('5.8'), Decimal('56.5'), Decimal('34.6'), Decimal('27.5'), Decimal('51.5'), 8201, 98),
#  (37, 'Fuller Park', Decimal('3.2'), Decimal('51.2'), Decimal('33.9'), Decimal('26.6'), Decimal('44.9'), 10432, 97),
#  (68, 'Englewood', Decimal('3.8'), Decimal('46.6'), Decimal('28.0'), Decimal('28.5'), Decimal('42.5'), 11888, 94),
#  (29, 'North Lawndale', Decimal('7.4'), Decimal('43.1'), Decimal('21.2'), Decimal('27.6'), Decimal('42.7'), 12034, 87),
#  (27, 'East Garfield Park', Decimal('8.2'), Decimal('42.4'), Decimal('19.6'), Decimal('21.3'), Decimal('43.2'), 12961, 83)]

# %%
# Problem 8: Which community area(number) is most crime prone?
# %sql select COMMUNITY_AREA_NUMBER, COUNT(COMMUNITY_AREA_NUMBER) AS NUMBER_OF_CASE FROM CHICAGO_CRIME_DATA group by COMMUNITY_AREA_NUMBER ORDER BY NUMBER_OF_CASE DESC LIMIT 1
# Out:
#  * ibm_db_sa://pzt67887:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(25, Decimal('43'))]

# %%
# Problem 9: Use a sub-query to find the name of the community area with highest hardship index.
# %sql select COMMUNITY_AREA_NAME, HARDSHIP_INDEX FROM CENSUS_DATA where HARDSHIP_INDEX = (select MAX(HARDSHIP_INDEX) FROM CENSUS_DATA)
# Out:
#  * ibm_db_sa://pzt67887:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Riverdale', 98)]

# %%
# Problem 10: Use a sub-query to determine the Community Area Name with most number of crimes?
# %sql select community_area_number,count(community_area_number) as occurence from CHICAGO_CRIME_DATA group by community_area_number order by occurence desc limit 1
# Out:
#  * ibm_db_sa://pzt67887:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(25, Decimal('43'))]

# %%
# %sql select community_area_name,community_area_number from CENSUS_DATA where community_area_number = 25
# Out:
#  * ibm_db_sa://pzt67887:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Austin', 25)]
